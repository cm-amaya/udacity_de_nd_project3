# %%
import pandas as pd
import configparser
from time import time
import matplotlib.pyplot as plt
import pandas.io.sql as sqlio

# %%
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

# %%
import psycopg2 
conn = psycopg2.connect("host={} dbname={} user={} password={} port={}".format(*config['CLUSTER'].values()))
cur = conn.cursor()

# %% [markdown]
# **Checking Staging Tables**

# %%
staging_events_sample_sql = "select * from staging_events limit 5;"
staging_events_sample = sqlio.read_sql_query(staging_events_sample_sql, conn)

# %%
staging_events_sample.head()
# Out:
#                       artist       auth firstname gender  iteminsession  \
# 0  N.E.R.D. FEATURING MALICE  Logged In    Jayden      M              0
# 1                       None  Logged In   Stefany      F              0
# 2        Death Cab for Cutie  Logged In   Stefany      F              1
# 3           Tracy Gang Pussy  Logged In   Stefany      F              2
# 4                    Skillet  Logged In     Kevin      M              0
#
#    lastname  length level                  location method      page  \
# 0       Fox   288.0  free  New Orleans-Metairie, LA    PUT  NextSong
# 1     White     NaN  free               Lubbock, TX    GET      Home
# 2     White   216.0  free               Lubbock, TX    PUT  NextSong
# 3     White   221.0  free               Lubbock, TX    PUT  NextSong
# 4  Arellano   178.0  free   Harrisburg-Carlisle, PA    PUT  NextSong
#
#    registration  sessionid                             song  status  \
# ...

# %%
staging_songs_sample_sql = "select * from staging_songs limit 5;"
staging_songs_sample = sqlio.read_sql_query(staging_songs_sample_sql, conn)

# %%
staging_songs_sample.head()
# Out:
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARJNIUY12298900C91              NaN               NaN
# 1          1  AR1KTV21187B9ACD72             34.0            -118.0
# 2          1  ARD8E0V1187FB5C3DB             40.0             -74.0
# 3          1  AR9FZZ71187FB4CE11              NaN               NaN
# 4          1  ARL26PR1187FB576E5              NaN               NaN
#
#      artist_location     artist_name             song_id  \
# 0                       Adelitas Way  SOBLFFE12AF72AA5BA
# 1    California - LA        Cristina  SOSMJFC12A8C13DE0C
# 2       New York, NY             Poe  SOSRVUJ12AB018731E
# 3                     Thomas Dutronc  SOFHCKF12A8C13C0BC
# 4  Glasgow, Scotland  Camera Obscura  SOLRWTN12AC90719FF
#
#                    title  duration  year
# 0                 Scream     213.0  2009
# 1  Is That All There Is?     343.0     0
# 2          Walk the Walk     290.0  2000
# 3              China Boy     171.0  2007
# ...

# %% [markdown]
# **Check fact table**

# %%
songplays_sample_sql = "select * from songplays limit 5;"
songplays_sample = sqlio.read_sql_query(songplays_sample_sql, conn)

# %%
songplays_sample.head()
# Out:
#    songplay_id          start_time  user_id level             song_id  \
# 0            5 2018-11-24 04:31:30       29  paid  SOAECHX12A6D4FC3D9
# 1           15 2018-11-23 17:29:09       58  paid  SOOWUWR12A8C13A62C
# 2           22 2018-11-26 18:34:29       92  free  SOZDGSX12A8C139AA7
# 3           23 2018-11-18 19:24:51       29  paid  SOCOWCL12A8C1415F7
# 4           24 2018-11-17 23:49:45       70  paid  SOKUCXB12A6D4FAC0C
#
#             artist_id  session_id                           location  \
# 0  ARX2DLI1187FB4DD03         709  Atlanta-Sandy Springs-Roswell, GA
# 1  ARI7RGN1187FB40849         852     Augusta-Richmond County, GA-SC
# 2  ARYPTWE1187FB49D64         938                      Palestine, TX
# 3  AR8K3HD1187B9B9CA9         589  Atlanta-Sandy Springs-Roswell, GA
# 4  ARHO39G1187FB4E31B         113      San Antonio-New Braunfels, TX
#
#                                           user_agent
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# ...

# %% [markdown]
# **Check Dimension Tables**

# %%
users_sample_sql = "select * from users limit 5;"
users_sample = sqlio.read_sql_query(users_sample_sql, conn)

# %%
users_sample.head()
# Out:
#    user_id first_name last_name gender level
# 0        6    Cecilia     Owens      F  free
# 1       11  Christian    Porter      F  free
# 2       14   Theodore    Harris      M  free
# 3       20      Aiden   Ramirez      M  paid
# 4       32       Lily     Burns      F  free

# %%
songs_sample_sql = "select * from songs limit 5;"
songs_sample = sqlio.read_sql_query(songs_sample_sql, conn)

# %%
songs_sample.head()
# Out:
#               song_id                                     title  \
# 0  SOAAAQN12AB01856D3                      Campeones De La Vida
# 1  SOAACTC12AB0186A20                  Christmas Is Coming Soon
# 2  SOAAETA12A6D4FC626                                     Shine
# 3  SOAAFHQ12A6D4F836E      Ridin' Rims (Explicit Album Version)
# 4  SOAAFUV12AB018831D  Where Do The Children Play? (LP Version)
#
#             artist_id  year  duration
# 0  ARAMIDF1187FB3D8D4     0     153.0
# 1  ARXWFZ21187FB43A0B  2008     180.0
# 2  ARQXK0B1187B9ACC97  2007     448.0
# 3  AR3CQ2D1187B9B1953  2006     322.0
# 4  AR5ZGC11187FB417A3     0     216.0

# %%
artists_sample_sql = "select * from artists limit 5;"
artists_sample = sqlio.read_sql_query(artists_sample_sql, conn)

# %%
artists_sample.head()
# Out:
#             artist_id                                       name  \
# 0  AR01IP11187B9AF5D2                           Call To Preserve
# 1  AR02LMQ1187B992AC9                          The Classic Crime
# 2  AR03Z7E1187FB44816  The Colourfield Featuring Sinead O'Connor
# 3  AR04PRW1187FB4D60D                                   The Bens
# 4  AR04S8J1187FB48358                             Clifford Brown
#
#               location  latitude  longitude
# 0   Rockledge, Florida      28.0      -80.0
# 1          Seattle, WA      47.0     -122.0
# 2  Manchester, England      53.0       -2.0
# 3                            NaN        NaN
# 4       Wilmington, DE      39.0      -75.0

# %%
time_sample_sql = "select * from time limit 5;"
time_sample = sqlio.read_sql_query(time_sample_sql, conn)

# %%
time_sample.head()
# Out:
#            start_time  hour  day  week  month  year  weekday
# 0 2018-11-01 21:01:46    21    1    44     11  2018        4
# 1 2018-11-01 21:11:13    21    1    44     11  2018        4
# 2 2018-11-01 21:42:00    21    1    44     11  2018        4
# 3 2018-11-01 22:23:14    22    1    44     11  2018        4
# 4 2018-11-02 01:29:36     1    2    44     11  2018        5

# %%
conn.close()
